# %%
import pandas as pd
import numpy as np
import lxml

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_cities_in_India_by_population')

# %%
len(tables)
# Out:
# 3

# %%
table1 = tables[0]
print(type(table1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
table1.head()
# Out:
#    Rank       City Population(2011)[3] Population(2001)  \
# 0     1     Mumbai            12442373         11978450
# 1     2      Delhi            11007835          9879172
# 2     3  Bangalore             8425970          4301326
# 3     4  Hyderabad             6809970          3637483
# 4     5  Ahmedabad             5570585          3520085
#
#   State or union territory
# 0              Maharashtra
# 1                    Delhi
# 2                Karnataka
# 3                Telangana
# 4                  Gujarat

# %%
table1
# Out:
#      Rank            City Population(2011)[3] Population(2001)  \
# 0       1          Mumbai            12442373         11978450
# 1       2           Delhi            11007835          9879172
# 2       3       Bangalore             8425970          4301326
# 3       4       Hyderabad             6809970          3637483
# 4       5       Ahmedabad             5570585          3520085
# ..    ...             ...                 ...              ...
# 318   319          Tezpur              102505            83028
# 319   320   Jehanabad[35]              102456            81503
# 320   321  Aurangabad[36]              101520            79393
# 321   322         Gangtok              100286            29354
# 322   323   Vasco Da Gama              100000                ―
#
#     State or union territory
# 0                Maharashtra
# 1                      Delhi
# 2                  Karnataka
# 3                  Telangana
# 4                    Gujarat
# ...

# %%
table1.rename(columns={"Population(2011)[3]":"Population(2011)"},inplace=True)
table1
# Out:
#      Rank            City Population(2011) Population(2001)  \
# 0       1          Mumbai         12442373         11978450
# 1       2           Delhi         11007835          9879172
# 2       3       Bangalore          8425970          4301326
# 3       4       Hyderabad          6809970          3637483
# 4       5       Ahmedabad          5570585          3520085
# ..    ...             ...              ...              ...
# 318   319          Tezpur           102505            83028
# 319   320   Jehanabad[35]           102456            81503
# 320   321  Aurangabad[36]           101520            79393
# 321   322         Gangtok           100286            29354
# 322   323   Vasco Da Gama           100000                ―
#
#     State or union territory
# 0                Maharashtra
# 1                      Delhi
# 2                  Karnataka
# 3                  Telangana
# 4                    Gujarat
# ..                       ...
# 318                    Assam
# ...

# %%
values = ['―','–','—']
table1.replace(values,np.nan,inplace = True)
table1.dropna(axis = 0,inplace = True)
table1["Population(2001)"].unique()
# Out:
# array(['11978450', '9879172', '4301326', '3637483', '3520085', '4343645',
#        '4572876', '2433835', '2538473', '2322575', '2185927', '2551337',
#        '2052066', '1474968', '1262551', '1437354', '1345938', '1012472',
#        '1366444', '1306227', '968256', '1398467', '1275134', '1077236',
#        '1079968', '1055938', '1039405', '967476', '1193512', '693350',
#        '1091918', '898440', '873311', '1065327', '966862', '704002',
#        '975393', '1007532', '827026', '932484', '930882', '851282',
#        '851051', '928869', '605747', '694316', '808515', '809895',
#        '872478', '786195', '762408', '752066', '718395', '672315',
#        '344543', '173542', '669087', '706043', '648032', '696760',
#        '530636', '520388', '462280', '514461', '368618', '598741',
#        '455754', '622701', '529690', '549510', '305058', '573096',
#        '556366', '534654', '279102', '596473', '378428', '511085',
#        '426674', '493405', '475439', '426354', '430733', '493167',
# ...

# %%
table1.iloc[40,2]= 1050721 
table1["Population(2011)"] = table1["Population(2011)"].astype(float)
table1["Population(2001)"] = table1["Population(2001)"].astype(float)
x = ((table1["Population(2011)"]-table1["Population(2001)"])/table1["Population(2001)"])*100
y = (((table1["Population(2011)"]/table1["Population(2001)"])**(1/10))-1)*100

# %%
table1["basic growth rate %"] = x
table1["average growth rate %"]= y

# %%
table1
# Out:
#      Rank            City  Population(2011)  Population(2001)  \
# 0       1          Mumbai        12442373.0        11978450.0
# 1       2           Delhi        11007835.0         9879172.0
# 2       3       Bangalore         8425970.0         4301326.0
# 3       4       Hyderabad         6809970.0         3637483.0
# 4       5       Ahmedabad         5570585.0         3520085.0
# ..    ...             ...               ...               ...
# 317   318       Buxar[34]          102591.0           83168.0
# 318   319          Tezpur          102505.0           83028.0
# 319   320   Jehanabad[35]          102456.0           81503.0
# 320   321  Aurangabad[36]          101520.0           79393.0
# 321   322         Gangtok          100286.0           29354.0
#
#     State or union territory  basic growth rate %  average growth rate %
# 0                Maharashtra             3.872980               0.380709
# 1                      Delhi            11.424672               1.087658
# ...

# %%
data_table1 = table1.sort_values(by=["basic growth rate %","City"],ascending=False)
data_table1.reset_index(drop=True,inplace=True)
data_table1
# Out:
#      Rank           City  Population(2011)  Population(2001)  \
# 0      56        Gurgaon          876824.0          173542.0
# 1      90           Loni          512296.0          120945.0
# 2     322        Gangtok          100286.0           29354.0
# 3      97      Erode[17]          498129.0          173600.0
# 4     106          Karur          444506.0          158955.0
# ..    ...            ...               ...               ...
# 294   132         Kollam          349033.0          361560.0
# 295   268  Machilipatnam          169892.0          179353.0
# 296   257      Serampore          181842.0          197857.0
# 297   120       Bhatpara          390467.0          442385.0
# 298   185      New Delhi          249998.0          302147.0
#
#     State or union territory  basic growth rate %  average growth rate %
# 0                    Haryana           405.251755              17.584691
# 1              Uttar Pradesh           323.577659              15.529609
# ...

# %%
data_table2 = table1.sort_values(by=["average growth rate %"],ascending=False)
data_table2.reset_index(drop=True,inplace=True) 
data_table2
# Out:
#      Rank           City  Population(2011)  Population(2001)  \
# 0      56        Gurgaon          876824.0          173542.0
# 1      90           Loni          512296.0          120945.0
# 2     322        Gangtok          100286.0           29354.0
# 3      97      Erode[17]          498129.0          173600.0
# 4     106          Karur          444506.0          158955.0
# ..    ...            ...               ...               ...
# 294   132         Kollam          349033.0          361560.0
# 295   268  Machilipatnam          169892.0          179353.0
# 296   257      Serampore          181842.0          197857.0
# 297   120       Bhatpara          390467.0          442385.0
# 298   185      New Delhi          249998.0          302147.0
#
#     State or union territory  basic growth rate %  average growth rate %
# 0                    Haryana           405.251755              17.584691
# 1              Uttar Pradesh           323.577659              15.529609
# ...

# %%
rank1=data_table1.sort_values(by="Rank")

# %%
rank2=data_table2.sort_values(by="Rank")

# %%
rank1
# Out:
#      Rank            City  Population(2011)  Population(2001)  \
# 283     1          Mumbai        12442373.0        11978450.0
# 240     2           Delhi        11007835.0         9879172.0
# 13      3       Bangalore         8425970.0         4301326.0
# 16      4       Hyderabad         6809970.0         3637483.0
# 30      5       Ahmedabad         5570585.0         3520085.0
# ..    ...             ...               ...               ...
# 142   318       Buxar[34]          102591.0           83168.0
# 141   319          Tezpur          102505.0           83028.0
# 120   320   Jehanabad[35]          102456.0           81503.0
# 109   321  Aurangabad[36]          101520.0           79393.0
# 2     322         Gangtok          100286.0           29354.0
#
#     State or union territory  basic growth rate %  average growth rate %
# 283              Maharashtra             3.872980               0.380709
# 240                    Delhi            11.424672               1.087658
# ...

# %%
rank2
# Out:
#      Rank            City  Population(2011)  Population(2001)  \
# 283     1          Mumbai        12442373.0        11978450.0
# 240     2           Delhi        11007835.0         9879172.0
# 13      3       Bangalore         8425970.0         4301326.0
# 16      4       Hyderabad         6809970.0         3637483.0
# 30      5       Ahmedabad         5570585.0         3520085.0
# ..    ...             ...               ...               ...
# 142   318       Buxar[34]          102591.0           83168.0
# 141   319          Tezpur          102505.0           83028.0
# 120   320   Jehanabad[35]          102456.0           81503.0
# 109   321  Aurangabad[36]          101520.0           79393.0
# 2     322         Gangtok          100286.0           29354.0
#
#     State or union territory  basic growth rate %  average growth rate %
# 283              Maharashtra             3.872980               0.380709
# 240                    Delhi            11.424672               1.087658
# ...

# %%
rank1.to_csv("rank1.csv")

# %%
rank1.to_csv("rank2.csv")
